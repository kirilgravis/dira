# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'https://www.dira.moch.gov.il/ProjectsList'
# Create object page
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
# parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <html><body><p>ï»¿<!DOCTYPE html>
#
# </p>
# <!-- Google Tag Manager -->
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-59973H');</script>
# <!-- End Google Tag Manager -->
# <title>××ª×¨ ×××¨×©×× ××××¨×××ª "×××¨× ××× ××"</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# ...

# %%
# Obtain information from tag <table>
table1 = soup.find('table', id="table-apartments")
table1

# %%
# Obtain every title of columns with tag <th>
headers = []
for i in table1.find_all('th'):
    title = i.text
    headers.append(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Obtain every title of columns with tag <th>
#       2 headers = []
# ----> 3 for i in table1.find_all('th'):
#       4     title = i.text
#       5     headers.append(title)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
<table style="text-align: right" ng-table="tableParams" wt-responsive-table="" class="table-apartments responsive ng-scope ng-table">
                    <thead>
                        <tr>
                            <th class="text-center">הרשמה</th>
                            <th>סוג הגרלה</th>
                            <th class="text-center">מספר הגרלה</th>
                            <th class="text-center">זכאות</th>
                            <!-- <th class="text-center">תחילת הרשמה</th>-->
                            <th class="text-center">סיום הרשמה</th>
                            <th class="text-center">יישוב</th>
                            <th class="text-center">קבלן</th>
                            <th class="text-center">דירות בהגרלה</th>
                            <th class="text-center">מתוכם דירות לבני מקום</th>
                            <th class="text-center">נרשמים בהגרלה</th>
                            <th class="text-center">מתוכם נרשמים בני מקום</th>
                            <th class="text-center">
                                מחיר למטר
                                <div class="red-color" style="font-size:7px;width:70%;margin:auto">
                                    כולל מע"מ (מלבד אילת)
                                    וללא הצמדה.
                                </div>
                                <div class="red-color" style="font-size:7px;width:70%;margin:auto">
                                    במחיר מטרה המחיר לפני הנחה
                                </div>
                            </th>
                            <th class="text-center">מענק</th>
                            <th class="text-center"></th>
                            <!--<th class="text-center"></th>-->
                        </tr>
                    </thead>
                    <tbody><!-- ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope" style="">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2352</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">אחים אוזן חברה לבניה בע"מ</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">אחים אוזן חברה לבניה בע"מ</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                102&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 35</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,575</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,440</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 14" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2353</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">מ.ב.צ. יזמות והשקעות בע"מ</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">מ.ב.צ. יזמות והשקעות בע"מ</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                85&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 29</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,659</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,433</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 7" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2354</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">אביסרור משה ובניו עבודות בנין ופתוח</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">אביסרור משה ובניו עבודות בנין ופתוח</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                81&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 28</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,831</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,475</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 5" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2355</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">א.ד.מ. בוני ישראל יזמות ובניה בע"מ </a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">א.ד.מ. בוני ישראל יזמות ובניה בע"מ </div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                81&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 28</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,616</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,438</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 18" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2356</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">קרדן נדל"ן יזום ופיתוח בע"מ</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">קרדן נדל"ן יזום ופיתוח בע"מ</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                78&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 27</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,635</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,438</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 10" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2357</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">רמי צרפתי חברה לבניה בע"מ</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">רמי צרפתי חברה לבניה בע"מ</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                55&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 19</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">23,658</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">1,451</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,729.60</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪0</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט 15" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data --><tr ng-repeat="project in $data" class="ng-scope">
                        <td data-title="'הרשמה'" class="col-align" header-class="'text-center'" style="min-width:115px;">
                            <!--when eligibility drawing to lottery-->
                            <div ng-show="eligibilityId != null &amp;&amp; project.IsForAplicant">
                                <button class="btn-table-gray">רשום</button>
                                <div class="table-link">
                                    <a ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" class="table-link" ng-click="drawingLotteries(project,false)">לביטול ההרשמה</a>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false" class="ng-hide">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2358</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">קריית גת</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">וינדור בקריה בע"מ      (שימו לב, מאפייני התכנון במתחם מותאמים לאוכלוסיה החרדית)</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">וינדור בקריה בע"מ      (שימו לב, מאפייני התכנון במתחם מותאמים לאוכלוסיה החרדית)</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                

                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery-->

                            <div ng-show="eligibilityId!= null &amp;&amp; isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)">
                                <div ng-show="project.IsForAplicant == false">
                                    <button class="btn-table-green" ng-click="drawingLotteries(project,true)">להרשמה</button>
                                </div>
                            </div>
                            <!--when eligibility not drawing to lottery and end date passed-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp;  project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" class="ng-hide">
                                סגור
                            </div>
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                התקיימה הגרלה
                            </div>
                            <!--when eligibility not drawing to lottery and start date preview-->
                            <div ng-show="eligibilityId!=null &amp;&amp; project.IsForAplicant!= true &amp;&amp; (isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null)" class="ng-hide">
                                טרם נפתח
                            </div>
                            <!--anonymous user -->

                            <div ng-show="eligibilityId==null" class="ng-hide">
                                <!--when eligibility not drawing to lottery and end date passed-->
                                <div ng-show="project.IsLotteryHeld==false &amp;&amp; isClosedLottery(project.ApplicationEndDate)" tool-tip="" title="ההרשמה הסתיימה" class="ng-isolate-scope ng-hide">
                                    סגור
                                </div>
                                <div ng-show="project.IsLotteryHeld &amp;&amp; !isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="התקיימה הגרלה" class="ng-isolate-scope ng-hide">
                                    התקיימה הגרלה
                                </div>
                                <!--when eligibility not drawing to lottery and start date preview-->
                                <div ng-show="isPreviewLottery(project.ApplicationStartDate,project.ApplicationEndDate) || project.ApplicationStartDate == null" tool-tip="" title="ההרשמה טרם נפתחה" class="ng-isolate-scope ng-hide">
                                    טרם נפתח
                                </div>
                                <div ng-show="isRellevantLottery(project.ApplicationStartDate,project.ApplicationEndDate)" tool-tip="" title="להרשמה יש להיכנס כמשתמש רשום לאתר" class="ng-isolate-scope">
                                    <button class="btn-table-green">להרשמה</button>
                                </div>
                            </div>
                        </td>
                        <td style="min-width:66px;" data-title="סוג הגרלה">
                            <!-- ngIf: project.OriginalLottery > 0 -->
                            <!-- ngIf: project.OriginalLottery == 0 --><span class="projectList-contentItem ng-scope" ng-if="project.OriginalLottery == 0"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/new-lottery.png" title="הגרלה ראשונה"></span><!-- end ngIf: project.OriginalLottery == 0 -->
                            <!-- <span class="projectList-contentItem" ng-if="project.SpecialLottery != null"><img style="padding-bottom: 5px;" tool-tip title="{{project.SpecialLotteryDescription}}" src="../../../../content/themes/images/agrala_gdola.png" /></span>
                                                <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.LotteryType == 5"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehchir_lamishtaper.png" title="מחיר למשתפר" /></span>

                    <span ng-show="isSearch==true" class="projectList-contentItem" ng-if="project.ProcessCode == 2 && ![21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mishtaken 23 icon.png" title="מחיר למשתכן" /></span>-->
                            <!--13.1.21-->
                            <!--<span ng-show="isSearch==true" class="projectList-contentItem" ng-if="[21,22].includes(project.ResponsibilityCode)"><img style="padding-bottom: 5px;" src="../../../../content/themes/images/mehir_mufhat 23 icon.png" title="מחיר מופחת" /></span>-->	<!--13.1.21-->
                        </td>
                        <td data-title="מספר הגרלה" class="ng-binding">2377</td>
                        <td data-title="זכאות" class="ng-binding">
                            חסרי דיור
                        </td>
                        <!--<td>{{project.ApplicationStartDate == null ?'טרם נפתחה הרשמה' : project.ApplicationStartDate| date:"dd/MM/yyyy" }}</td>-->
                        <td data-title="סיום הרשמה" class="ng-binding">07/02/2024</td>
                        <td data-title="יישוב" class="ng-binding">רכסים</td>
                        <td data-title="קבלן">
                            <div class="table-link"><a ng-click="showContractorSite(project.ProjectURL)" ng-show="project.ProjectURL" class="ng-binding ng-hide">עץ השקד נדל"ן בע"מ</a></div>
                            <div ng-hide="project.ProjectURL" class="ng-binding">עץ השקד נדל"ן בע"מ</div>
                        </td>
                        <td data-title="דירות בהגרלה">
                            <!-- ngIf: project.LotteryApparmentsNum != -1 --><div ng-if="project.LotteryApparmentsNum != -1" class="ng-binding ng-scope">
                                <!-- ngIf: project.ResponsibilityCode == 90 -->
                                117&nbsp;
                            </div><!-- end ngIf: project.LotteryApparmentsNum != -1 -->
                            <!-- ngIf: project.LotteryApparmentsNum == -1 -->
                        </td>
                        <td data-title="מתוכם דירות לבני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope"> 40</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td data-title="נרשמים בהגרלה" class="ng-binding">5,947</td>
                        <td data-title="מתוכם נרשמים בני מקום">
                            <!-- ngIf: project.ResponsibilityCode != 90 --><span ng-if="project.ResponsibilityCode != 90" class="ng-binding ng-scope">483</span><!-- end ngIf: project.ResponsibilityCode != 90 -->
                            <!-- ngIf: project.ResponsibilityCode == 90 -->
                        </td>
                        <td class="price ng-isolate-scope" tool-tip="" tp-text="[23, 24].includes(project.ResponsibilityCode) ? title : ''" title="" style="min-width: 115px" data-title="
                                מחיר למטר
                                
                                    כולל מע&quot;מ (מלבד אילת)
                                    וללא הצמדה.
                                
                                
                                    במחיר מטרה המחיר לפני הנחה
                                
                            ">
                            <div ng-class="{price: [23,24].includes(project.ResponsibilityCode)}" ng-show="project.ResponsibilityCode != 90 &amp;&amp; (project.PricePerUnit!= 0 || (project.ContractorCode != null &amp;&amp; project.ContractorCode != 999))" class="ng-binding price"><span ng-show="[23,24].includes(project.ResponsibilityCode)">*</span> ₪12,696.84</div>
                            <div ng-show="project.ResponsibilityCode != 90 &amp;&amp; project.PricePerUnit== 0 &amp;&amp; (project.ContractorCode == 999 || project.ContractorCode == null)" class="ng-hide">במכרז</div>
                            <div ng-show="project.ResponsibilityCode == 90" class="ng-hide">לא רלוונטי</div>
                        </td>
                        <td data-title="מענק">
                            <div class="ng-binding">₪40,000</div>
                            <div>&nbsp;</div>
                        </td>
                        <td>
                            <button style="width:115px" type="button" class="btn btn-default btn-sm btn-table ng-isolate-scope" ng-click="showProjectInfo(project)" tool-tip="" title="פרויקט מגרשים 127,135-139" tooltip1-placement="bottom">
                                <span ng-show="project.IsLotteryHeld==false">פרטים&nbsp;</span>
                                <span ng-show="project.IsLotteryHeld" class="ng-hide">פרטים ותוצאות&nbsp;</span>
                                <span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span>
                            </button>
                        </td><!--ng-disabled="project.ShowAppartments == false" ng-class="{'btn-table-disable':project.ShowAppartments == false}" -->
                        <!--<td><button type="button" class="btn btn-default btn-sm btn-table" style="padding-bottom:12px;" tool-tip title="דירות בפרויקט {{project.ProjectName}}" ng-disabled="!project.ShowAppartments" ng-click="showApartmentsList(project)" href="">דירות&nbsp;<span class="glyphicon glyphicon-triangle-left" aria-hidden="true"></span></button></td>-->
                    </tr><!-- end ngRepeat: project in $data -->


                </tbody></table>
